# %%
import pandas as pd

# %%
BID = pd.read_csv('./dataset/BID1.csv')
BID.head(5)
# Out:
#   Symbol         Value TradingDate  Time   Open   High    Low  Close   Volume
# 0    BID  1.590710e+11   24/1/2014   NaN  19000  19500  18500  18800  8417060
# 1    BID  5.950934e+10   27/1/2014   NaN  18700  18800  18100  18400  3240910
# 2    BID  1.713530e+10    6/2/2014   NaN  18200  18300  17600  17600   959590
# 3    BID  5.025221e+10    7/2/2014   NaN  17400  17500  16500  16600  2987600
# 4    BID  6.791783e+10   10/2/2014   NaN  16500  17200  16200  17000  4052090

# %%
from sklearn.model_selection import train_test_split

# %%
X = BID[["Open"]]
X.head()
# Out:
#     Open
# 0  19000
# 1  18700
# 2  18200
# 3  17400
# 4  16500

# %%
y = BID["Close"]
y.head()
# Out:
# 0    18800
# 1    18400
# 2    17600
# 3    16600
# 4    17000
# Name: Close, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 1)

print('Labels counts in y:', len(y))
print('Labels counts in y_train:', len(y_train))
print('Labels counts in y_test:', len(y_test))
# Out:
# Labels counts in y: 2432
# Labels counts in y_train: 1945
# Labels counts in y_test: 487

# %%
from sklearn.linear_model import LinearRegression

# %%
# Tạo mô hình Linear Regression dùng sklearn
lr = LinearRegression()

# Fit mô hình với train data
lr.fit(X_train.values.reshape(-1, 1), y_train)

# Predict trên test data dùng mô hình đã train
y_pred_test = lr.predict(X_test.values.reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Tính MSE trên test data
mse = mean_squared_error(y_test, y_pred_test)

# In ra MSE
print(f'The test MSE is {mse}')

# Tính R-squred score trên test data
r2 = r2_score(y_test, y_pred_test)

# In ra R-squred score
print(f'The test R-squred score is {r2}')
# Out:
# The test MSE is 489499.3186113227
# The test R-squred score is 0.9962684809622424

# %%
import matplotlib.pyplot as plt

# %%
# Vẽ biểu đồ gồm dữ liệu với đường hồi quy tuyến tính (linear regression line)
fig, ax = plt.subplots()
ax.scatter(X, y, label = 'data points')

# Vẽ biểu đồ gồm test data và predicted output trên test data
ax.plot(X_test, y_pred_test, color='red', linewidth = 2, label = 'model predictions')
ax.set_xlabel('Open')
ax.set_ylabel('Close')
ax.legend()

# %%
X = BID[["High"]]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 1)

# Tạo mô hình Linear Regression dùng sklearn
lr = LinearRegression()

# Fit mô hình với train data
lr.fit(X_train.values.reshape(-1, 1), y_train)

# Predict trên test data dùng mô hình đã train
y_pred_test = lr.predict(X_test.values.reshape(-1,1))

# Tính MSE trên test data
mse = mean_squared_error(y_test, y_pred_test)

# In ra MSE
print(f'The test MSE is {mse}')

# Tính R-squred score trên test data
r2 = r2_score(y_test, y_pred_test)

# In ra R-squred score
print(f'The test R-squred score is {r2}')

fig, ax = plt.subplots()
ax.scatter(X, y, label = 'data points')

# Vẽ biểu đồ gồm test data và predicted output trên test data
ax.plot(X_test, y_pred_test, color='red', linewidth = 2, label = 'model predictions')
ax.set_xlabel('High')
ax.set_ylabel('Close')
ax.legend()
# Out:
# The test MSE is 243639.0508544195
# The test R-squred score is 0.998142706798482

# %%
X = BID[["Low"]]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 1)

# Tạo mô hình Linear Regression dùng sklearn
lr = LinearRegression()

# Fit mô hình với train data
lr.fit(X_train.values.reshape(-1, 1), y_train)

# Predict trên test data dùng mô hình đã train
y_pred_test = lr.predict(X_test.values.reshape(-1,1))

# Tính MSE trên test data
mse = mean_squared_error(y_test, y_pred_test)

# In ra MSE
print(f'The test MSE is {mse}')

# Tính R-squred score trên test data
r2 = r2_score(y_test, y_pred_test)

# In ra R-squred score
print(f'The test R-squred score is {r2}')

fig, ax = plt.subplots()
ax.scatter(X, y, label = 'data points')

# Vẽ biểu đồ gồm test data và predicted output trên test data
ax.plot(X_test, y_pred_test, color='red', linewidth = 2, label = 'model predictions')
ax.set_xlabel('Low')
ax.set_ylabel('Close')
ax.legend()
# Out:
# The test MSE is 231260.26427744643
# The test R-squred score is 0.9982370719508328

# %%
X = BID[["Volume"]]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 1)

# Tạo mô hình Linear Regression dùng sklearn
lr = LinearRegression()

# Fit mô hình với train data
lr.fit(X_train.values.reshape(-1, 1), y_train)

# Predict trên test data dùng mô hình đã train
y_pred_test = lr.predict(X_test.values.reshape(-1,1))

# Tính MSE trên test data
mse = mean_squared_error(y_test, y_pred_test)

# In ra MSE
print(f'The test MSE is {mse}')

# Tính R-squred score trên test data
r2 = r2_score(y_test, y_pred_test)

# In ra R-squred score
print(f'The test R-squred score is {r2}')

fig, ax = plt.subplots()
ax.scatter(X, y, label = 'data points')

# Vẽ biểu đồ gồm test data và predicted output trên test data
ax.plot(X_test, y_pred_test, color='red', linewidth = 2, label = 'model predictions')
ax.set_xlabel('Volume')
ax.set_ylabel('Close')
ax.legend()
# Out:
# The test MSE is 131461198.09830971
# The test R-squred score is -0.002146366254256238

# %%
inputCols = ["Open", "High", "Low", "Volume"]
X = BID[inputCols]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 1)

# Tạo mô hình Linear Regression dùng sklearn
lr = LinearRegression()

# Fit mô hình với train data
lr.fit(X_train.values.reshape(-1, 4), y_train)

# Predict trên test data dùng mô hình đã train
y_pred_test = lr.predict(X_test.values.reshape(-1,4))

# Tính MSE trên test data
mse = mean_squared_error(y_test, y_pred_test)

# In ra MSE
print(f'The test MSE is {mse}')

# Tính R-squred score trên test data
r2 = r2_score(y_test, y_pred_test)

# In ra R-squred score
print(f'The test R-squred score is {r2}')
# Out:
# The test MSE is 111836.02067145897
# The test R-squred score is 0.9991474589966203

# %%
inputCols = ["Open", "High", "Low"]
X = BID[inputCols]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size = 0.2, random_state = 1)

# Tạo mô hình Linear Regression dùng sklearn
lr = LinearRegression()

# Fit mô hình với train data
lr.fit(X_train.values.reshape(-1, 3), y_train)

# Predict trên test data dùng mô hình đã train
y_pred_test = lr.predict(X_test.values.reshape(-1,3))

# Tính MSE trên test data
mse = mean_squared_error(y_test, y_pred_test)

# In ra MSE
print(f'The test MSE is {mse}')

# Tính R-squred score trên test data
r2 = r2_score(y_test, y_pred_test)

# In ra R-squred score
print(f'The test R-squred score is {r2}')
# Out:
# The test MSE is 110702.30263904417
# The test R-squred score is 0.9991561014814216

# %%
# Khởi tạo một list để lưu các giá trị MSE cho mỗi mô hình
mse_train_list = []
mse_test_list = []
coef_list = []
intercept_list = []

# Tạo một list các kết hợp có thể có của các thuộc tính để tạo các mô hình khác nhau
cols = [['Open'],['High'],['Low'],['Open','High'],['Open','Low'],['High','Low'],['Open','High','Low']]

# Lặp qua tất cả các kết hợp có thể có
for i in cols:
    # Thiết lập mỗi bộ kết hợp trong list trên như là `X`
    X = BID[i]
    
    # Thiết lập "Close" như là `y`
    y = BID["Close"]
   
    # Tách data thành train/test sets với tỷ lệ 80%/20% 
    # Thiết lập random_state = 0 (random_state ảnh hưởng đến tính ngẫu nhiên ở mỗi lần chạy)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

    # Khởi tạo một Linear Regression model
    lr = LinearRegression()

    # Fit mô hình trên train data
    lr.fit(X_train, y_train)
    
    # Predict trên train và test data dùng mô hình đã huấn luyện
    y_train_pred = lr.predict(X_train)
    y_test_pred = lr.predict(X_test)
    
    # Tính MSE trên train và test data
    mse_train = mean_squared_error(y_train, y_train_pred)
    mse_test = mean_squared_error(y_test, y_test_pred)
    
    # Thêm Train MSE và Test MSE vào kết quả
    mse_train_list.append(mse_train)
    mse_test_list.append(mse_test)
    
    # Thêm các hệ số của mỗi mô hình vào kết quả
    coef_list.append(lr.coef_)
    intercept_list.append(lr.intercept_)

# %%
print("Intercept\tCoeficients\tTrain MSE\tTest MSE")
for i in range(len(mse_train_list)):
    print(f'{intercept_list[i]}\t{coef_list[i]}\t{mse_train_list[i]}\t{mse_test_list[i]}')
# Out:
# Intercept	Coeficients	Train MSE	Test MSE
# 282.1471208434741	[0.99118978]	927246.9727987729	596753.5679864754
# 217.4169525968464	[0.97839099]	642665.6723465824	191243.7040621222
# 188.60528105010235	[1.0085952]	669829.2604825859	353629.05196226196
# 217.13625060781487	[-0.10356328  1.08040578]	640100.7811649492	190379.66910836662
# 185.3828030602599	[-0.08717232  1.09713036]	668139.0053973981	351080.2691582962
# 186.3828735993702	[0.53338678 0.4593437 ]	579963.4819738782	167776.2950222597
# 161.62177285284633	[-0.63639498  0.82994559  0.80030852]	517659.24378266215	91823.89099599067

# %% [markdown]
# ## Model selection cho Ridge Regression dùng phương pháp holdout

# %%
X = BID[['Open','High','Low']]
y = BID[['Close']]

X_train_val, X_test, y_train_val, y_test = train_test_split(X, y, test_size = 0.2, random_state = 1)

X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size = 0.25, random_state = 1)

# %%
from sklearn.linear_model import Ridge

# %%
# Create three lists for train, validation, and test MSE
train_mse = []
val_mse = []
test_mse = []

# List of hyper-parameter values 
#alphas = [1e-8, 1e-6,1e-4, 1e-2, 0.0, 1e2, 1e4, 1e6, 1e8]
#alphas = [1e-2, 0.0, 1e2, 5e2, 1e3, 5e3, 1e4, 5e4, 1e5, 5e5, 1e6, 5e6, 1e7, 5e7, 1e8]
#alphas = [1e5, 5e5, 1e6, 5e6, 6e6, 7e6, 8e6, 9e6, 1e7, 5e7, 1e8]
#alphas = [8e6, 9e6, 9e6 + 2e5, 9e6 + 4e5, 9e6 + 6e5, 9e6 + 8e5, 1e7, 5e7, 1e8]
alphas = [1e2, 1e3, 1e4, 1e5, 1e6,1e7, 1e8, 1e9]

# Loop over all the alpha values
for alpha in alphas:
    # Tạo mô hình Ridge regression với tham số alpha
    ridge_reg = Ridge(alpha)

    # Fit mô hình trên train data
    ridge_reg.fit(X_train, y_train)
    
    # Predict trên train set 
    y_train_pred = ridge_reg.predict(X_train)
    
    # Predict trên validation set 
    y_val_pred = ridge_reg.predict(X_val)

    # Predict trên test set 
    y_test_pred = ridge_reg.predict(X_test)
    
    # Tính train, validation, và test MSE
    mse_train = mean_squared_error(y_train, y_train_pred) 
    mse_val = mean_squared_error(y_val, y_val_pred)
    mse_test = mean_squared_error(y_test, y_test_pred)
    
    # Thêm các MSE vào các list tương ứng
    train_mse.append(mse_train)
    val_mse.append(mse_val)
    test_mse.append(mse_test)
    
    # In ra train, validation, và test MSE theo alpha
    print('alpha: {:7} | train mse: {:5} | val mse: {:5} | test mse: {:5}'.
          format(alpha, round(mse_train, 2), round(mse_val, 2), round(mse_test, 2)))
# Out:
# alpha:   100.0 | train mse: 647788.24 | val mse: 110262.69 | test mse: 112926.04
# alpha:  1000.0 | train mse: 647788.24 | val mse: 110262.55 | test mse: 112925.82
# alpha: 10000.0 | train mse: 647788.24 | val mse: 110261.19 | test mse: 112923.54
# alpha: 100000.0 | train mse: 647788.31 | val mse: 110247.66 | test mse: 112900.82
# alpha: 1000000.0 | train mse: 647795.08 | val mse: 110119.27 | test mse: 112681.63
# alpha: 10000000.0 | train mse: 648396.74 | val mse: 109448.23 | test mse: 111199.6
# alpha: 100000000.0 | train mse: 672732.9 | val mse: 125720.63 | test mse: 123616.63
# alpha: 1000000000.0 | train mse: 771073.99 | val mse: 211061.79 | test mse: 200687.85

# %%
# Chọn giá trị alpha (hyper-parameter), cho val mse nhỏ nhất trên validation data 
best_alpha = 10000000

# In ra best alpha (hyper-parameter)
print(f'The best alpha (hyper-parameter) value, alpha = {best_alpha}')
# Out:
# The best alpha (hyper-parameter) value, alpha = 10000000

# %%
fig, ax = plt.subplots(figsize = (12, 8))

# Vẽ biểu đồ train MSE theo các giá trị alpha
ax.plot(alphas, train_mse, 's--', label = 'Train error', color = 'blue', linewidth = 2)

# Vẽ biểu đồ validation MSE theo các giá trị alpha
ax.plot(alphas, val_mse, 's-', label = 'Val error',color ='green', linewidth = 2)

# Vẽ biểu đồ test MSE theo các giá trị alpha
ax.plot(alphas, test_mse, 's-', label = 'Test error',color ='purple', linewidth = 2)

# Vẽ đường thẳng đứng ứng với best alpha
ax.axvline(best_alpha, 0, 0.5, color = 'r', label = f'Min validation error at alpha = {best_alpha}')

ax.set_xlabel('Value of Alpha', fontsize = 15)
ax.set_ylabel('Mean Squared Error',fontsize = 15)
ax.set_ylim([15, 55])
ax.legend(loc = 'upper left', fontsize = 16)
ax.set_title('Mean Squared Error', fontsize = 20)
ax.set_xscale('log')
plt.tight_layout()
plt.show();
